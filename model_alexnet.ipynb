# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\hasin\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\hasin\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hasin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hasin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hasin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hasin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hasin\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in c:\users\hasin\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hasin\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hasin\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hasin\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\hasin\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\hasin\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\hasin\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hasin\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hasin\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hasin\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hasin\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Define constants
IMAGE_SIZE = 227
BATCH_SIZE = 64
NUM_CLASSES = 3
EPOCHS = 50

# Define data directories
train_dir = os.path.join(os.getcwd(), 'Ivy Gourd_Data', 'train')
valid_dir = os.path.join(os.getcwd(), 'Ivy Gourd_Data', 'val')
test_dir = os.path.join(os.getcwd(), 'Ivy Gourd_Data', 'test')

# Define data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Training data generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Validation data generator
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_directory(
    valid_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Test data generator
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Define the AlexNet model
model = Sequential()
model.add(Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Conv2D(256, (5, 5), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Conv2D(384, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(384, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator
)

# Evaluate the model on the test data
loss, accuracy = model.evaluate(test_generator)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

# Make predictions on the test data
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes

# Print the confusion matrix
print("Confusion Matrix")
print(confusion_matrix(y_true, y_pred_classes))

# Print the classification report
target_names = list(test_generator.class_indices.keys())
print("Classification Report")
print(classification_report(y_true, y_pred_classes, target_names=target_names))

# Calculate the accuracy manually
accuracy_manual = np.mean(y_pred_classes == y_true)
print('Manual Accuracy Calculation:', accuracy_manual)

# Calculate precision, recall, and F1 score
report = classification_report(y_true, y_pred_classes, target_names=target_names, output_dict=True)
precision = report['weighted avg']['precision']
recall = report['weighted avg']['recall']
f1_score = report['weighted avg']['f1-score']

# Print precision, recall, and F1 score
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1_score)
# Out:
# Found 526 images belonging to 3 classes.
# Found 149 images belonging to 3 classes.
# Found 79 images belonging to 3 classes.
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 160s 17s/step - accuracy: 0.3498 - loss: 8.4365 - val_accuracy: 0.3356 - val_loss: 1.1004
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 105s 12s/step - accuracy: 0.3384 - loss: 1.1009 - val_accuracy: 0.3356 - val_loss: 1.0994
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3365 - loss: 1.0988 - val_accuracy: 0.3356 - val_loss: 1.0988
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 105s 12s/step - accuracy: 0.3384 - loss: 1.0988 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 13s/step - accuracy: 0.3346 - loss: 1.0991 - val_accuracy: 0.3356 - val_loss: 1.0989
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 105s 12s/step - accuracy: 0.3346 - loss: 1.0987 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 105s 12s/step - accuracy: 0.3346 - loss: 1.0985 - val_accuracy: 0.3356 - val_loss: 1.0988
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3346 - loss: 1.0987 - val_accuracy: 0.3356 - val_loss: 1.0990
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 103s 12s/step - accuracy: 0.3365 - loss: 1.0998 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3251 - loss: 1.0998 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 179s 21s/step - accuracy: 0.3289 - loss: 1.0987 - val_accuracy: 0.3356 - val_loss: 1.0988
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 13s/step - accuracy: 0.3346 - loss: 1.0991 - val_accuracy: 0.3356 - val_loss: 1.0990
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3251 - loss: 1.0996 - val_accuracy: 0.3356 - val_loss: 1.0989
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 105s 12s/step - accuracy: 0.3270 - loss: 1.1000 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3289 - loss: 1.0991 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 213s 25s/step - accuracy: 0.3327 - loss: 1.0986 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 105s 12s/step - accuracy: 0.3080 - loss: 1.1000 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 13s/step - accuracy: 0.3308 - loss: 1.0997 - val_accuracy: 0.3356 - val_loss: 1.0990
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 105s 12s/step - accuracy: 0.3308 - loss: 1.0992 - val_accuracy: 0.3356 - val_loss: 1.0988
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3099 - loss: 1.1005 - val_accuracy: 0.3289 - val_loss: 1.0992
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.2985 - loss: 1.1006 - val_accuracy: 0.3289 - val_loss: 1.0987
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3004 - loss: 1.0995 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 103s 12s/step - accuracy: 0.3517 - loss: 1.0981 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 103s 12s/step - accuracy: 0.3498 - loss: 1.0984 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3517 - loss: 1.0978 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 107s 12s/step - accuracy: 0.3479 - loss: 1.0984 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3346 - loss: 1.0999 - val_accuracy: 0.3356 - val_loss: 1.0990
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3365 - loss: 1.0991 - val_accuracy: 0.3356 - val_loss: 1.0989
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3346 - loss: 1.0987 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 105s 12s/step - accuracy: 0.3289 - loss: 1.0993 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 13s/step - accuracy: 0.3232 - loss: 1.1000 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 106s 12s/step - accuracy: 0.2966 - loss: 1.1004 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3118 - loss: 1.0992 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 173s 20s/step - accuracy: 0.3232 - loss: 1.0997 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 103s 12s/step - accuracy: 0.3213 - loss: 1.0993 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1354s 168s/step - accuracy: 0.3099 - loss: 1.0988 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 104s 12s/step - accuracy: 0.3118 - loss: 1.0993 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 414s 50s/step - accuracy: 0.3289 - loss: 1.0994 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 120s 15s/step - accuracy: 0.3232 - loss: 1.0996 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 124s 14s/step - accuracy: 0.3175 - loss: 1.0988 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2333s 290s/step - accuracy: 0.3555 - loss: 1.0990 - val_accuracy: 0.3356 - val_loss: 1.0988
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.3346 - loss: 1.0994 - val_accuracy: 0.3356 - val_loss: 1.0989
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 125s 14s/step - accuracy: 0.3536 - loss: 1.0987 - val_accuracy: 0.3356 - val_loss: 1.0990
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 124s 14s/step - accuracy: 0.3251 - loss: 1.0989 - val_accuracy: 0.3356 - val_loss: 1.0988
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 128s 14s/step - accuracy: 0.3270 - loss: 1.0985 - val_accuracy: 0.3356 - val_loss: 1.0986
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 123s 14s/step - accuracy: 0.3422 - loss: 1.0991 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 124s 14s/step - accuracy: 0.3460 - loss: 1.1001 - val_accuracy: 0.3356 - val_loss: 1.0988
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 124s 14s/step - accuracy: 0.3346 - loss: 1.0993 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 124s 14s/step - accuracy: 0.3308 - loss: 1.0996 - val_accuracy: 0.3356 - val_loss: 1.0987
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 124s 14s/step - accuracy: 0.3270 - loss: 1.0988 - val_accuracy: 0.3356 - val_loss: 1.0987
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.3418 - loss: 1.0981
# Test loss: 1.0981276035308838
# Test accuracy: 0.3417721390724182
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# Confusion Matrix
# [[ 0  0 27]
#  [ 0  0 25]
#  [ 0  0 27]]
# Classification Report
#                        precision    recall  f1-score   support
#
#      Ivy Gourd damage       0.00      0.00      0.00        27
#       Ivy Gourd fresh       0.00      0.00      0.00        25
# Ivy Gourd half damage       0.34      1.00      0.51        27
#
#              accuracy                           0.34        79
#             macro avg       0.11      0.33      0.17        79
#          weighted avg       0.12      0.34      0.17        79
#
# Manual Accuracy Calculation: 0.34177215189873417
# Precision: 0.11680820381349143
# Recall: 0.34177215189873417
# F1 Score: 0.17411034153331742
# C:\Users\hasin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hasin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hasin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hasin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hasin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hasin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
